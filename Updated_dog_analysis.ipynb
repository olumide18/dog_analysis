# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Timestamp
import warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
df=pd.read_csv('/Users/USER/Pictures/dog.csv')
df
# Out:
#                    Best in show?  Unnamed: 1               largest value  \
# 0         we rated 87 dog breeds         NaN              smallest value
# 1     Sources - see bottom right         NaN                    category
# 2                      Dog breed         NaN  American Kennel Club group
# 3                  Border Collie         NaN                     herding
# 4                 Border Terrier         NaN                     terrier
# ..                           ...         ...                         ...
# 172                   Weimaraner         NaN                    sporting
# 173                Welsh Terrier         NaN                     terrier
# 174             Wire Fox Terrier         NaN                     terrier
# 175  Wirehaired Pointing Griffon         NaN                    sporting
# 176               Xoloitzcuintli         NaN                non-sporting
#
#      Unnamed: 3     Unnamed: 4  \
# 0           NaN            NaN
# ...

# %% [markdown]
# # data cleaning

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                 Best in show?  Unnamed: 1               largest value  \
# 0      we rated 87 dog breeds         NaN              smallest value
# 1  Sources - see bottom right         NaN                    category
# 2                   Dog breed         NaN  American Kennel Club group
# 3               Border Collie         NaN                     herding
# 4              Border Terrier         NaN                     terrier
#
#    Unnamed: 3     Unnamed: 4  \
# 0         NaN            NaN
# 1         NaN  datadog score
# 2         NaN            NaN
# 3         NaN           3.64
# 4         NaN           3.61
#
#                                                  160  \
# 0                                                  1
# 1                                   POPULARITY IN US
# 2  1- 173, 1 = most poular, US. American Kennel C...
# 3                                                 45
# 4                                                 80
#
# ...

# %% [markdown]
# # RENAMING THE HEADER

# %%
df1 = df.rename(columns={'Best in show?': 'Dog breed',
                        'largest value': 'Category', '160': 'Popularity Ranking', '$26,686': 'Lifetime Cost', '80':'TRAINABILITY',
                         '16.50': 'LONGEVITY', 'Unnamed: 4':'dog score', '9':'NO. OF GENETIC AILMENTS', '2,680':'Avg price(USA)',
                         '$1,349':'food costs per year', '3':'grooming required', '3.1':'suitability for children', 'Unnamed: 25':'intelligence + longevity + ailments + cost',
                         'Unnamed: 26':'TOP DATA DOG MEGA RANKING (without kids)', 'Unnamed: 27':'TOP DATA DOG MEGA RANKING (with kids)',
                         'Unnamed: 28':'intelligence + longevity + ailments + 50% purchase', 'Unnamed: 29':'POPULAR RATING','Unnamed: 31':'Size',
                         'Unnamed: 32':'weight (kg)', 'Unnamed: 33':'weight (lbs)','Unnamed: 34':'shoulder height (cm)', 'Unnamed: 35':'shoulder height (in)',
                         'Unnamed: 40':'Intelligence', 'Unnamed: 44':'GENETIC DISEASES', '21,657':'LIFETIME COST', 'Unnamed: 51':'average purchase price (US $)',
                         'Unnamed: 52':'price bracket', 'Unnamed: 53':'Lowest Price Sold', 'Unnamed: 54':'Highest Price Sold','Unnamed: 55':'food per week',
                         'Unnamed: 59':'food per year','Unnamed: 60':'food per lifetime','Unnamed: 62':'Other regular costs per lifetime',
                         'Unnamed: 68':'vet fees per year', 'Unnamed: 23':'suitability % for children', 'Unnamed: 58': 'Food per week'
                    })
df1
# Out:
#                        Dog breed  Unnamed: 1                    Category  \
# 0         we rated 87 dog breeds         NaN              smallest value
# 1     Sources - see bottom right         NaN                    category
# 2                      Dog breed         NaN  American Kennel Club group
# 3                  Border Collie         NaN                     herding
# 4                 Border Terrier         NaN                     terrier
# ..                           ...         ...                         ...
# 172                   Weimaraner         NaN                    sporting
# 173                Welsh Terrier         NaN                     terrier
# 174             Wire Fox Terrier         NaN                     terrier
# 175  Wirehaired Pointing Griffon         NaN                    sporting
# 176               Xoloitzcuintli         NaN                non-sporting
#
#      Unnamed: 3      dog score  \
# 0           NaN            NaN
# ...

# %% [markdown]
# # DROPPING THE FIRST 3 ROWS

# %%
df1 = df1.drop([0,1,2], axis=0)
df1
# Out:
#                        Dog breed  Unnamed: 1      Category  Unnamed: 3  \
# 3                  Border Collie         NaN       herding         NaN
# 4                 Border Terrier         NaN       terrier         NaN
# 5                       Brittany         NaN      sporting         NaN
# 6                  Cairn Terrier         NaN       terrier         NaN
# 7         Welsh Springer Spaniel         NaN      sporting         NaN
# ..                           ...         ...           ...         ...
# 172                   Weimaraner         NaN      sporting         NaN
# 173                Welsh Terrier         NaN       terrier         NaN
# 174             Wire Fox Terrier         NaN       terrier         NaN
# 175  Wirehaired Pointing Griffon         NaN      sporting         NaN
# 176               Xoloitzcuintli         NaN  non-sporting         NaN
#
#     dog score Popularity Ranking   87 Lifetime Cost Unnamed: 8  Unnamed: 9  \
# ...

# %% [markdown]
# # DROPPING THE UNNECESSARY COLUMNS

# %%
df2 = df1.drop(['Unnamed: 1','Unnamed: 3','dog score', '87', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13',
               'Unnamed: 15','Unnamed: 17','NO. OF GENETIC AILMENTS', 'food costs per year',
               'Unnamed: 19', 'Unnamed: 21', 'suitability for children', 'Unnamed: 24', 'intelligence + longevity + ailments + cost',
               'TOP DATA DOG MEGA RANKING (without kids)', 'TOP DATA DOG MEGA RANKING (with kids)',
               'intelligence + longevity + ailments + 50% purchase', 'POPULAR RATING', 'Unnamed: 30', 'weight (kg)',
               'weight (lbs)', 'shoulder height (cm)', 'shoulder height (in)', 'Unnamed: 36', 'Unnamed: 37',
               'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'GENETIC DISEASES',
               'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'LIFETIME COST', 'Unnamed: 50',
               'price bracket', 'food per week', 'Unnamed: 56',
               'Unnamed: 57', 'food per year', 'food per lifetime', 'Unnamed: 61', 'Other regular costs per lifetime',
               'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
               'vet fees per year', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71', 'Unnamed: 72', 'Unnamed: 73',
               'Unnamed: 74', 'average purchase price (US $)'], axis=1)
df2
# Out:
#                        Dog breed      Category Popularity Ranking  \
# 3                  Border Collie       herding                 45
# 4                 Border Terrier       terrier                 80
# 5                       Brittany      sporting                 30
# 6                  Cairn Terrier       terrier                 59
# 7         Welsh Springer Spaniel      sporting                130
# ..                           ...           ...                ...
# 172                   Weimaraner      sporting                 32
# 173                Welsh Terrier       terrier                 99
# 174             Wire Fox Terrier       terrier                100
# 175  Wirehaired Pointing Griffon      sporting                 92
# 176               Xoloitzcuintli  non-sporting                155
#
#     Lifetime Cost TRAINABILITY LONGEVITY Avg price(USA) grooming required  \
# 3         $20,143            1     12.52           $623                 2
# ...

# %%
df2.columns = df2.columns.str.replace(' ', '_') # Replacing the space(s) each column
df2
# Out:
#                        Dog_breed      Category Popularity_Ranking  \
# 3                  Border Collie       herding                 45
# 4                 Border Terrier       terrier                 80
# 5                       Brittany      sporting                 30
# 6                  Cairn Terrier       terrier                 59
# 7         Welsh Springer Spaniel      sporting                130
# ..                           ...           ...                ...
# 172                   Weimaraner      sporting                 32
# 173                Welsh Terrier       terrier                 99
# 174             Wire Fox Terrier       terrier                100
# 175  Wirehaired Pointing Griffon      sporting                 92
# 176               Xoloitzcuintli  non-sporting                155
#
#     Lifetime_Cost TRAINABILITY LONGEVITY Avg_price(USA) grooming_required  \
# 3         $20,143            1     12.52           $623                 2
# ...

# %%
df2.to_excel('Updated_dogAnalysis.xlsx')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 3 to 176
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Dog_breed                   174 non-null    object
#  1   Category                    172 non-null    object
#  2   Popularity_Ranking          172 non-null    object
#  3   Lifetime_Cost               172 non-null    object
#  4   TRAINABILITY                172 non-null    object
#  5   LONGEVITY                   172 non-null    object
#  6   Avg_price(USA)              172 non-null    object
#  7   grooming_required           172 non-null    object
#  8   suitability_%_for_children  87 non-null     object
#  9   Size                        172 non-null    object
#  10  Intelligence                172 non-null    object
#  11  Lowest_Price_Sold           172 non-null    object
#  12  Highest_Price_Sold          172 non-null    object
# ...

# %%
df2.isnull().sum()# to check for null value
# Out:
# Dog_breed                      0
# Category                       2
# Popularity_Ranking             2
# Lifetime_Cost                  2
# TRAINABILITY                   2
# LONGEVITY                      2
# Avg_price(USA)                 2
# grooming_required              2
# suitability_%_for_children    87
# Size                           2
# Intelligence                   2
# Lowest_Price_Sold              2
# Highest_Price_Sold             2
# Food_per_week                  2
# dtype: int64

# %% [markdown]
# # # EDA...Exploratory data analysis

# %%
df2
# Out:
#                        Dog_breed      Category Popularity_Ranking  \
# 3                  Border Collie       herding                 45
# 4                 Border Terrier       terrier                 80
# 5                       Brittany      sporting                 30
# 6                  Cairn Terrier       terrier                 59
# 7         Welsh Springer Spaniel      sporting                130
# ..                           ...           ...                ...
# 172                   Weimaraner      sporting                 32
# 173                Welsh Terrier       terrier                 99
# 174             Wire Fox Terrier       terrier                100
# 175  Wirehaired Pointing Griffon      sporting                 92
# 176               Xoloitzcuintli  non-sporting                155
#
#     Lifetime_Cost TRAINABILITY LONGEVITY Avg_price(USA) grooming_required  \
# 3         $20,143            1     12.52           $623                 2
# ...
